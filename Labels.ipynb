# %%
from PIL import Image
import csv
file1 = open('/home/sahil/Desktop/CS 682/Project/Resized Image/RFMiD_Training_Labels.csv', 'r') 
#file2 = open('HW1 data_muskan_annotation.csv', 'r')

f1 = csv.DictReader(file1)

#f2 = csv.DictReader(file2)
#count = 0
for i in f1:
    #print(i)
    filename = int(i['\ufeffID'])
    directory = '/home/sahil/Desktop/CS 682/Project/Resized Image/training/'
    t = False
    if(int(i['DR']) == 1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/DR/'+str(filename)+'.png')
        t = True
    if(int(i['MH'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/MH/'+str(filename)+'.png')
        t = True
    if(int(i['ODC'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/ODC/'+str(filename)+'.png')
        t = True
    if(int(i['TSLN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/TSLN/'+str(filename)+'.png')
        t = True
    if(int(i['DN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/DN/'+str(filename)+'.png')
        t = True
    if(int(i['MYA'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/MYA/'+str(filename)+'.png')
        t = True
    if(t == False):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/training/NOTA/'+str(filename)+'.png')
# Out:
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/1.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/2.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/3.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/4.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/4.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/5.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/6.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/7.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/8.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/9.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/10.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/11.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/12.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/12.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/training/13.png
# ...

# %%
from PIL import Image
import csv
file1 = open('/home/sahil/Desktop/CS 682/Project/Resized Image/RFMiD_Testing_Labels.csv', 'r') 


f1 = csv.DictReader(file1)


for i in f1:
    #print(i)
    filename = int(i['\ufeffID'])
    directory = '/home/sahil/Desktop/CS 682/Project/Resized Image/test/'
    t = False
    if(int(i['DR']) == 1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/DR/'+str(filename)+'.png')
        t = True
    if(int(i['MH'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/MH/'+str(filename)+'.png')
        t = True
    if(int(i['ODC'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/ODC/'+str(filename)+'.png')
        t = True
    if(int(i['TSLN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/TSLN/'+str(filename)+'.png')
        t = True
    if(int(i['DN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/DN/'+str(filename)+'.png')
        t = True
    if(int(i['MYA'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/MYA/'+str(filename)+'.png')
        t = True
    if(t == False):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/NOTA/'+str(filename)+'.png')
# Out:
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/1.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/1.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/2.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/3.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/3.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/4.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/5.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/6.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/7.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/8.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/9.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/10.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/10.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/11.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/12.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/test/13.png
# ...

# %%
from PIL import Image
import csv
file1 = open('/home/sahil/Desktop/CS 682/Project/Resized Image/RFMiD_Validation_Labels.csv', 'r') 


f1 = csv.DictReader(file1)


for i in f1:
    #print(i)
    filename = int(i['\ufeffID'])
    directory = '/home/sahil/Desktop/CS 682/Project/Resized Image/Validation/'
    t = False
    if(int(i['DR']) == 1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/DR/'+str(filename)+'.png')
        t = True
    if(int(i['MH'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/MH/'+str(filename)+'.png')
        t = True
    if(int(i['ODC'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/ODC/'+str(filename)+'.png')
        t = True
    if(int(i['TSLN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/test/TSLN/'+str(filename)+'.png')
        t = True
    if(int(i['DN'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/DN/'+str(filename)+'.png')
        t = True
    if(int(i['MYA'])==1):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/MYA/'+str(filename)+'.png')
        t = True
    if(t == False):
        path = directory + str(filename) +'.png'
        print(path)
        file = Image.open(path)
        file.save('/home/sahil/Desktop/CS 682/Project/Resized Image/data/valid/NOTA/'+str(filename)+'.png')
# Out:
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/1.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/1.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/2.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/3.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/4.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/5.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/6.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/7.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/8.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/9.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/10.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/11.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/12.png
# /home/sahil/Desktop/CS 682/Project/Resized Image/Validation/13.png
# ...
